# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# ### Bit

# %% [markdown]
# Bit is a position in computer memory, that can keep '0' or '1'.

# %% [markdown]
# ### Byte

# %% [markdown]
# Byte is a group of 8 bits.
