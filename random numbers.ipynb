# %% [markdown]
# # random numbers

# %%
import numpy as np

# %% [markdown]
# ### float random numbers

# %% [markdown]
# .rand()

# %%
np.random.rand()
# Out:
# 0.20041954318840216

# %%
np.random.rand(5)
# Out:
# array([0.83166058, 0.8094528 , 0.44503101, 0.76095499, 0.96468104])

# %%
np.random.rand(3,2)
# Out:
# array([[0.28165249, 0.20236132],
#        [0.72732392, 0.14676092],
#        [0.64933839, 0.12673794]])

# %% [markdown]
# .sample()

# %%
np.random.sample((2,3))
# Out:
# array([[0.14232071, 0.19132769, 0.46357479],
#        [0.73508365, 0.49109412, 0.26919085]])

# %% [markdown]
# .uniform()

# %%
np.random.uniform(0, 10)
# Out:
# 0.9534349602773484

# %%
np.random.uniform(0, 10, size=(2,3))
# Out:
# array([[4.13527538, 6.57040864, 5.07689082],
#        [6.80173655, 6.68147982, 0.9649566 ]])

# %% [markdown]
# ### int random number

# %% [markdown]
# .randint()

# %%
np.random.randint(0,5)
# Out:
# 0

# %%
np.random.randint(0,5,size=(2,2))
# Out:
# array([[0, 0],
#        [3, 0]], dtype=int32)

# %% [markdown]
# ### to shuffle numbers

# %%
arr = np.arange(6)
print(arr)
arr0 = np.random.shuffle(arr)
print(arr0)
print(arr)
# Out:
# [0 1 2 3 4 5]
# [1 0 2 4 5 3]

# %%
arr0 = np.array([1, 2, 3, 4, 5])
arr1 = np.random.permutation(arr0)
print(arr0)
print(arr1)
# Out:
# [1 2 3 4 5]
# [3 4 5 1 2]

# %% [markdown]
# ### rabdom choice

# %%
arr0 = np.array([1, 2, 3, 4, 5])
arr1 = np.random.choice(arr0, size=(3,3), replace=True)
print(arr1)
arr1 = np.random.choice(arr0, size=(5), replace=False)
print(arr1)
# Out:
# [[2 3 4]
#  [3 4 1]
#  [3 3 2]]
# [2 4 5 1 3]

# %% [markdown]
# ### seed
# * max value of seed is uint32

# %%
np.iinfo(np.uint32)
# Out:
# iinfo(min=0, max=4294967295, dtype=uint32)

# %%
np.random.seed(12)
np.random.randint(0,100)
# Out:
# 75
