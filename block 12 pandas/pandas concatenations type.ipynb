# %% [markdown]
# # pandas concatenations type

# %%
import pandas as pd

# %% [markdown]
# ### inner
# - resulting table includes itmes, that are present in both tables
# - rows for which no match, are deleted

# %% [markdown]
# ![alt text](dst3-u1-md12_7_1.png)
