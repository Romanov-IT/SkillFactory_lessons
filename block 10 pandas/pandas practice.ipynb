# %% [markdown]
# # pandas practice

# %%
import pandas as pd

# %%
student_data = pd.read_csv("data/students_performance.csv", sep=",")
student_data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# * how many students table includs?
# * how many missing values are there in the table?
# * how many columns in table has date type "object"?

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# what is the writing score for a student with an index of 155?

# %%
student_data["writing score"][155]
# Out:
# np.int64(88)

# %% [markdown]
# what is avarage math score for students?

# %%
student_data["math score"].mean()
# Out:
# np.float64(66.089)

# %% [markdown]
# Which racial group is the largest in the educational institution?

# %%
display(student_data["race/ethnicity"].mode())
display(student_data.describe(include=["object"]).loc[:,"race/ethnicity"])
# Out:
# 0    group C
# Name: race/ethnicity, dtype: object
# count        1000
# unique          5
# top       group C
# freq          319
# Name: race/ethnicity, dtype: object
